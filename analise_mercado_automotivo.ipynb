# %%
pivot = df.pivot_table(index='Year', columns='Vehicle_Type', values='Sales', aggfunc='sum')

pivot.plot()

plt.title('Evolução das Vendas por Tipo de Veículo')
plt.xlabel('Ano')
plt.ylabel('Vendas')
plt.show()

# %%
growth = df.groupby('Year')['Sales'].sum().pct_change() * 100

print(growth)
# Out:
# Year
# 2018          NaN
# 2019     6.285714
# 2020   -10.035842
# 2021    12.549801
# 2022    15.044248
# 2023    13.846154
# Name: Sales, dtype: float64

# %%
total = df['Sales'].sum()
electric = df[df['Vehicle_Type'] == 'Electric']['Sales'].sum()

percent = (electric / total) * 100

print(f"Participação dos elétricos: {percent:.2f}%")
# Out:
# Participação dos elétricos: 5.37%

# %%
df.groupby('Vehicle_Type')['Sales'].sum().plot(kind='bar')

plt.title('Vendas por Tipo de Veículo')
plt.show()

# %%
import matplotlib.pyplot as plt

df.groupby('Year')['Sales'].sum().plot()

plt.title('Vendas de Veículos ao Longo do Tempo')
plt.xlabel('Ano')
plt.ylabel('Vendas')
plt.show()

# %%
import pandas as pd

df = pd.read_csv('carros.csv')

df.head()
# Out:
#    Year Vehicle_Type  Sales
# 0  2018   Combustion  50000
# 1  2018       Hybrid   2000
# 2  2018     Electric    500
# 3  2019   Combustion  52000
# 4  2019       Hybrid   3000
